# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        #print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | barreirinhas
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | angoche
# Processing Record 9 of Set 1 | half moon bay
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | okhotsk
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | grand centre
# Processing Record 14 of Set 1 | mbini
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | belaya gora
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | verkhnevilyuysk
# Processing Record 19 of Set 1 | saqqez
# Processing Record 20 of Set 1 | pemangkat
# Processing Record 21 of Set 1 | mataura
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | la macarena
# Processing Record 25 of Set 1 | tigil
# Processing Record 26 of Set 1 | nome
# Processing Record 27 of Set 1 | broken hill
# Processing Record 28 of Set 1 | barcelos
# Processing Record 29 of Set 1 | rikitea
# Processing Record 30 of Set 1 | cockburn town
# Processing Record 31 of Set 1 | katherine
# Processing Record 32 of Set 1 | tsihombe
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | tiksi
# Processing Record 36 of Set 1 | richards bay
# Processing Record 37 of Set 1 | funadhoo
# Processing Record 38 of Set 1 | agua verde
# Processing Record 39 of Set 1 | san matias
# Processing Record 40 of Set 1 | muskegon
# Processing Record 41 of Set 1 | empangeni
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | bathsheba
# Processing Record 44 of Set 1 | gat
# Processing Record 45 of Set 1 | la asuncion
# Processing Record 46 of Set 1 | barentsburg
# Processing Record 47 of Set 1 | naze
# Processing Record 48 of Set 1 | jalu
# Processing Record 49 of Set 1 | east london
# Processing Record 50 of Set 1 | srandakan
# Processing Record 0 of Set 2 | avarua
# Processing Record 1 of Set 2 | kapaa
# Processing Record 2 of Set 2 | pacific grove
# Processing Record 3 of Set 2 | requena
# Processing Record 4 of Set 2 | kesennuma
# Processing Record 5 of Set 2 | ikskile
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | ancud
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | taolanaro
# Processing Record 10 of Set 2 | ilulissat
# Processing Record 11 of Set 2 | hasaki
# Processing Record 12 of Set 2 | fort nelson
# Processing Record 13 of Set 2 | ambodifototra
# Processing Record 14 of Set 2 | illoqqortoormiut
# Processing Record 15 of Set 2 | babanusah
# Processing Record 16 of Set 2 | pokhara
# Processing Record 17 of Set 2 | nizhneyansk
# Processing Record 18 of Set 2 | lithgow
# Processing Record 19 of Set 2 | harper
# Processing Record 20 of Set 2 | karakol
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | kavaratti
# Processing Record 23 of Set 2 | namatanai
# Processing Record 24 of Set 2 | stoyba
# Processing Record 25 of Set 2 | nouadhibou
# Processing Record 26 of Set 2 | satun
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | eureka
# Processing Record 29 of Set 2 | clyde river
# Processing Record 30 of Set 2 | olafsvik
# Processing Record 31 of Set 2 | hermanus
# Processing Record 32 of Set 2 | inirida
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | saint-leu
# Processing Record 35 of Set 2 | grand river south east
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | nakuru
# Processing Record 39 of Set 2 | langarud
# Processing Record 40 of Set 2 | marzuq
# Processing Record 41 of Set 2 | ribeira grande
# Processing Record 42 of Set 2 | palmer
# Processing Record 43 of Set 2 | kalianget
# Processing Record 44 of Set 2 | challans
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | sur
# Processing Record 47 of Set 2 | miyako
# Processing Record 48 of Set 2 | bengkulu
# Processing Record 49 of Set 2 | urengoy
# Processing Record 0 of Set 3 | bethel
# Processing Record 1 of Set 3 | viedma
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | bukene
# Processing Record 4 of Set 3 | comodoro rivadavia
# Processing Record 5 of Set 3 | vila franca do campo
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | roma
# Processing Record 8 of Set 3 | xichang
# Processing Record 9 of Set 3 | constitucion
# Processing Record 10 of Set 3 | elk city
# Processing Record 11 of Set 3 | revelstoke
# Processing Record 12 of Set 3 | torbay
# Processing Record 13 of Set 3 | louisbourg
# Processing Record 14 of Set 3 | kvarkeno
# Processing Record 15 of Set 3 | san patricio
# Processing Record 16 of Set 3 | camara de lobos
# Processing Record 17 of Set 3 | hami
# Processing Record 18 of Set 3 | carauari
# Processing Record 19 of Set 3 | netanya
# Processing Record 20 of Set 3 | bedele
# Processing Record 21 of Set 3 | talnakh
# Processing Record 22 of Set 3 | adrar
# Processing Record 23 of Set 3 | newport
# Processing Record 24 of Set 3 | brus laguna
# Processing Record 25 of Set 3 | belushya guba
# Processing Record 26 of Set 3 | marcona
# Processing Record 27 of Set 3 | taksimo
# Processing Record 28 of Set 3 | esperance
# Processing Record 29 of Set 3 | sao filipe
# Processing Record 30 of Set 3 | nanortalik
# Processing Record 31 of Set 3 | funchal
# Processing Record 32 of Set 3 | road town
# Processing Record 33 of Set 3 | hilo
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | nizwa
# Processing Record 36 of Set 3 | dunedin
# Processing Record 37 of Set 3 | saint george
# Processing Record 38 of Set 3 | kahului
# Processing Record 39 of Set 3 | buraydah
# Processing Record 40 of Set 3 | vanavara
# Processing Record 41 of Set 3 | zhigansk
# Processing Record 42 of Set 3 | chodavaram
# Processing Record 43 of Set 3 | atuona
# Processing Record 44 of Set 3 | nabire
# Processing Record 45 of Set 3 | oistins
# Processing Record 46 of Set 3 | cherskiy
# Processing Record 47 of Set 3 | mahibadhoo
# Processing Record 48 of Set 3 | hithadhoo
# Processing Record 49 of Set 3 | mount gambier
# Processing Record 0 of Set 4 | sechura
# Processing Record 1 of Set 4 | sharjah
# Processing Record 2 of Set 4 | upernavik
# Processing Record 3 of Set 4 | pevek
# Processing Record 4 of Set 4 | chuy
# Processing Record 5 of Set 4 | nishihara
# Processing Record 6 of Set 4 | luebo
# Processing Record 7 of Set 4 | ponta do sol
# Processing Record 8 of Set 4 | san cristobal
# Processing Record 9 of Set 4 | eyl
# Processing Record 10 of Set 4 | riberalta
# Processing Record 11 of Set 4 | binga
# Processing Record 12 of Set 4 | kembe
# Processing Record 13 of Set 4 | solovetskiy
# Processing Record 14 of Set 4 | kununurra
# Processing Record 15 of Set 4 | meulaboh
# Processing Record 16 of Set 4 | nieuw nickerie
# Processing Record 17 of Set 4 | namie
# Processing Record 18 of Set 4 | yellowknife
# Processing Record 19 of Set 4 | lakselv
# Processing Record 20 of Set 4 | mahebourg
# Processing Record 21 of Set 4 | serra
# Processing Record 22 of Set 4 | iqaluit
# Processing Record 23 of Set 4 | port lincoln
# Processing Record 24 of Set 4 | sentyabrskiy
# Processing Record 25 of Set 4 | bella vista
# Processing Record 26 of Set 4 | santa maria da vitoria
# Processing Record 27 of Set 4 | port-gentil
# Processing Record 28 of Set 4 | mys shmidta
# Processing Record 29 of Set 4 | koslan
# Processing Record 30 of Set 4 | bredasdorp
# Processing Record 31 of Set 4 | chumikan
# Processing Record 32 of Set 4 | amderma
# Processing Record 33 of Set 4 | lahat
# Processing Record 34 of Set 4 | payakumbuh
# Processing Record 35 of Set 4 | cayenne
# Processing Record 36 of Set 4 | lypova dolyna
# Processing Record 37 of Set 4 | mazagao
# Processing Record 38 of Set 4 | vostok
# Processing Record 39 of Set 4 | pflugerville
# Processing Record 40 of Set 4 | kousseri
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | kaitangata
# Processing Record 43 of Set 4 | elizabeth city
# Processing Record 44 of Set 4 | kloulklubed
# Processing Record 45 of Set 4 | glenwood springs
# Processing Record 46 of Set 4 | maceio
# Processing Record 47 of Set 4 | amli
# Processing Record 48 of Set 4 | san andres
# Processing Record 49 of Set 4 | karla
# Processing Record 0 of Set 5 | onnaing
# Processing Record 1 of Set 5 | thompson
# Processing Record 2 of Set 5 | cabo san lucas
# Processing Record 3 of Set 5 | sharan
# Processing Record 4 of Set 5 | sheridan
# Processing Record 5 of Set 5 | hambantota
# Processing Record 6 of Set 5 | lavrentiya
# Processing Record 7 of Set 5 | kastamonu
# Processing Record 8 of Set 5 | poum
# Processing Record 9 of Set 5 | buala
# Processing Record 10 of Set 5 | naya bazar
# Processing Record 11 of Set 5 | kiama
# Processing Record 12 of Set 5 | smolenka
# Processing Record 13 of Set 5 | karratha
# Processing Record 14 of Set 5 | belyy yar
# Processing Record 15 of Set 5 | butaritari
# Processing Record 16 of Set 5 | cidreira
# Processing Record 17 of Set 5 | penzance
# Processing Record 18 of Set 5 | carnarvon
# Processing Record 19 of Set 5 | la libertad
# Processing Record 20 of Set 5 | victoria
# Processing Record 21 of Set 5 | mut
# Processing Record 22 of Set 5 | anau
# Processing Record 23 of Set 5 | ajdabiya
# Processing Record 24 of Set 5 | dondo
# Processing Record 25 of Set 5 | grindavik
# Processing Record 26 of Set 5 | isabela
# Processing Record 27 of Set 5 | provideniya
# Processing Record 28 of Set 5 | beringovskiy
# Processing Record 29 of Set 5 | laiagam
# Processing Record 30 of Set 5 | tuatapere
# Processing Record 31 of Set 5 | tahlequah
# Processing Record 32 of Set 5 | karaul
# Processing Record 33 of Set 5 | leshan
# Processing Record 34 of Set 5 | coihaique
# Processing Record 35 of Set 5 | monze
# Processing Record 36 of Set 5 | kaeo
# Processing Record 37 of Set 5 | sao joao da barra
# Processing Record 38 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 5 | wenzhou
# Processing Record 40 of Set 5 | saldanha
# Processing Record 41 of Set 5 | saleaula
# Processing Record 42 of Set 5 | liverpool
# Processing Record 43 of Set 5 | mangan
# Processing Record 44 of Set 5 | sumenep
# Processing Record 45 of Set 5 | matara
# Processing Record 46 of Set 5 | traverse city
# Processing Record 47 of Set 5 | mayo
# Processing Record 48 of Set 5 | korsakovo
# Processing Record 49 of Set 5 | la ronge
# Processing Record 0 of Set 6 | bara
# Processing Record 1 of Set 6 | jumla
# Processing Record 2 of Set 6 | itoman
# Processing Record 3 of Set 6 | burkburnett
# Processing Record 4 of Set 6 | banda aceh
# Processing Record 5 of Set 6 | vardo
# Processing Record 6 of Set 6 | segezha
# Processing Record 7 of Set 6 | vila do maio
# Processing Record 8 of Set 6 | nalut
# Processing Record 9 of Set 6 | patna
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | sabang
# Processing Record 12 of Set 6 | apollonia
# Processing Record 13 of Set 6 | buchanan
# Processing Record 14 of Set 6 | sitka
# Processing Record 15 of Set 6 | tabiauea
# Processing Record 16 of Set 6 | qasigiannguit
# Processing Record 17 of Set 6 | mpulungu
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | moranbah
# Processing Record 20 of Set 6 | kardla
# Processing Record 21 of Set 6 | kavieng
# Processing Record 22 of Set 6 | gasa
# Processing Record 23 of Set 6 | orel-izumrud
# Processing Record 24 of Set 6 | shimoda
# Processing Record 25 of Set 6 | zapolyarnyy
# Processing Record 26 of Set 6 | myre
# Processing Record 27 of Set 6 | tasiilaq
# Processing Record 28 of Set 6 | kirakira
# Processing Record 29 of Set 6 | kargil
# Processing Record 30 of Set 6 | auki
# Processing Record 31 of Set 6 | ngunguru
# Processing Record 32 of Set 6 | bilibino
# Processing Record 33 of Set 6 | cape coast
# Processing Record 34 of Set 6 | laguna
# Processing Record 35 of Set 6 | kuche
# Processing Record 36 of Set 6 | sovetskiy
# Processing Record 37 of Set 6 | mount isa
# Processing Record 38 of Set 6 | narsaq
# Processing Record 39 of Set 6 | praia
# Processing Record 40 of Set 6 | severo-kurilsk
# Processing Record 41 of Set 6 | maku
# Processing Record 42 of Set 6 | sola
# Processing Record 43 of Set 6 | antalaha
# Processing Record 44 of Set 6 | khatanga
# Processing Record 45 of Set 6 | karakendzha
# Processing Record 46 of Set 6 | tommot
# Processing Record 47 of Set 6 | rawson
# Processing Record 48 of Set 6 | pepel
# Processing Record 49 of Set 6 | mwinilunga
# Processing Record 0 of Set 7 | prince rupert
# Processing Record 41 of Set 9 | porto santo
# Processing Record 42 of Set 9 | luanda
# Processing Record 43 of Set 9 | tiznit
# Processing Record 44 of Set 9 | lompoc
# Processing Record 45 of Set 9 | scharding
# Processing Record 46 of Set 9 | guicheng
# Processing Record 47 of Set 9 | smithers
# Processing Record 48 of Set 9 | khani
# Processing Record 49 of Set 9 | hun
# Processing Record 0 of Set 10 | opuwo
# Processing Record 1 of Set 10 | guerrero negro
# Processing Record 2 of Set 10 | ambilobe
# Processing Record 3 of Set 10 | meyungs
# Processing Record 4 of Set 10 | te anau
# Processing Record 5 of Set 10 | sosua
# Processing Record 6 of Set 10 | terrace bay
# Processing Record 7 of Set 10 | kargasok
# Processing Record 8 of Set 10 | sibolga
# Processing Record 9 of Set 10 | los llanos de aridane
# Processing Record 10 of Set 10 | victor harbor
# Processing Record 11 of Set 10 | neryungri
# Processing Record 12 of Set 10 | shingu
# Processing Record 13 of Set 10 | lolua
# Processing Record 14 of Set 10 | borba
# Processing Record 15 of Set 10 | madang
# Processing Record 16 of Set 10 | muros
# Processing Record 17 of Set 10 | byron bay
# Processing Record 18 of Set 10 | asfi
# Processing Record 19 of Set 10 | georgiyevka
# Processing Record 20 of Set 10 | qandala
# Processing Record 21 of Set 10 | lagoa
# Processing Record 22 of Set 10 | san juan
# Processing Record 23 of Set 10 | coquimbo
# Processing Record 24 of Set 10 | tilichiki
# Processing Record 25 of Set 10 | astanajapura
# Processing Record 26 of Set 10 | carbonia
# Processing Record 27 of Set 10 | dingle
# Processing Record 28 of Set 10 | geraldton
# Processing Record 29 of Set 10 | necochea
# Processing Record 30 of Set 10 | rio grande
# Processing Record 31 of Set 10 | madina
# Processing Record 32 of Set 10 | dalby
# Processing Record 33 of Set 10 | ferme-neuve
# Processing Record 34 of Set 10 | sept-iles
# Processing Record 35 of Set 10 | macae
# Processing Record 36 of Set 10 | kesan
# Processing Record 37 of Set 10 | tessaoua
# Processing Record 38 of Set 10 | nanakuli
# Processing Record 39 of Set 10 | tuy hoa
# Processing Record 40 of Set 10 | camopi
# Processing Record 41 of Set 10 | neubrandenburg
# Processing Record 42 of Set 10 | mirnyy
# Processing Record 43 of Set 10 | longyearbyen
# Processing Record 44 of Set 10 | capim grosso
# Processing Record 45 of Set 10 | show low
# Processing Record 46 of Set 10 | chara
# Processing Record 47 of Set 10 | khonuu
# Processing Record 48 of Set 10 | ahuimanu
# Processing Record 49 of Set 10 | san quintin
# Processing Record 0 of Set 11 | alofi
# Processing Record 1 of Set 11 | port augusta
# Processing Record 2 of Set 11 | rosarito
# Processing Record 3 of Set 11 | marystown
# Processing Record 4 of Set 11 | wanlaweyn
# Processing Record 5 of Set 11 | kotido
# Processing Record 6 of Set 11 | bani
# Processing Record 7 of Set 11 | saint-joseph
# Processing Record 8 of Set 11 | margate
# Processing Record 9 of Set 11 | manchester
# Processing Record 10 of Set 11 | moose factory
# Processing Record 11 of Set 11 | mzimba
# Processing Record 12 of Set 11 | stalybridge
# Processing Record 13 of Set 11 | manicore
# Processing Record 14 of Set 11 | nizhneangarsk
# Processing Record 15 of Set 11 | paamiut
# Processing Record 16 of Set 11 | shihezi
# Processing Record 17 of Set 11 | lata
# Processing Record 18 of Set 11 | ilhabela
# Processing Record 19 of Set 11 | luganville
# Processing Record 20 of Set 11 | trabzon
# Processing Record 21 of Set 11 | ordynskoye
# Processing Record 22 of Set 11 | ottumwa
# Processing Record 23 of Set 11 | inyonga
# Processing Record 24 of Set 11 | skiros
# Processing Record 25 of Set 11 | akdepe
# Processing Record 26 of Set 11 | shache
# Processing Record 27 of Set 11 | kulhudhuffushi
# Processing Record 28 of Set 11 | veraval
# Processing Record 29 of Set 11 | vaitupu
# Processing Record 30 of Set 11 | turukhansk
# Processing Record 31 of Set 11 | nador
# Processing Record 32 of Set 11 | vicuna
# Processing Record 33 of Set 11 | sudak
# Processing Record 34 of Set 11 | santa maria
# Processing Record 35 of Set 11 | havre-saint-pierre
# Processing Record 36 of Set 11 | kabare
# Processing Record 37 of Set 11 | kulu
# Processing Record 38 of Set 11 | salalah
# Processing Record 39 of Set 11 | general pico
# Processing Record 40 of Set 11 | alta floresta
# Processing Record 41 of Set 11 | vryburg
# Processing Record 42 of Set 11 | tombouctou
# Processing Record 43 of Set 11 | shepsi
# Processing Record 44 of Set 11 | redkino
# Processing Record 45 of Set 11 | brae
# Processing Record 46 of Set 11 | songea
# Processing Record 47 of Set 11 | tautira
# Processing Record 48 of Set 11 | ixtapa
# Processing Record 49 of Set 11 | yinchuan
# Processing Record 0 of Set 12 | cape canaveral
# Processing Record 1 of Set 12 | tumannyy
# Processing Record 2 of Set 12 | krasnoselkup
# Processing Record 3 of Set 12 | barbalha
# Processing Record 4 of Set 12 | santo amaro da imperatriz
# Processing Record 5 of Set 12 | odweyne
# Processing Record 6 of Set 12 | leningradskiy
# Processing Record 7 of Set 12 | phan rang
# Processing Record 8 of Set 12 | kismayo
# Processing Record 9 of Set 12 | alamosa
# Processing Record 10 of Set 12 | kachiry
# Processing Record 11 of Set 12 | presidencia roque saenz pena
# Processing Record 12 of Set 12 | daru
# Processing Record 13 of Set 12 | mahanoro
# Processing Record 14 of Set 12 | ponta delgada
# Processing Record 15 of Set 12 | cheuskiny
# Processing Record 16 of Set 12 | lalsot
# Processing Record 17 of Set 12 | barranca
# Processing Record 18 of Set 12 | zhemchuzhnyy
# Processing Record 19 of Set 12 | arlit
# Processing Record 20 of Set 12 | the valley
# Processing Record 21 of Set 12 | yurla
# Processing Record 22 of Set 12 | aleksandrovsk-sakhalinskiy
# Processing Record 23 of Set 12 | charters towers
# Processing Record 24 of Set 12 | sloboda
# Processing Record 25 of Set 12 | levski
# Processing Record 26 of Set 12 | kihei
# Processing Record 27 of Set 12 | lima
# Processing Record 28 of Set 12 | kefamenanu
# Processing Record 29 of Set 12 | muswellbrook
# Processing Record 30 of Set 12 | mugur-aksy
# Processing Record 31 of Set 12 | tawkar
# Processing Record 32 of Set 12 | santa cruz de la palma
# Processing Record 33 of Set 12 | panama city
# Processing Record 34 of Set 12 | mooi river
# Processing Record 35 of Set 12 | tocopilla
# Processing Record 36 of Set 12 | tabuk
# Processing Record 37 of Set 12 | srednekolymsk
# Processing Record 38 of Set 12 | flin flon
# Processing Record 39 of Set 12 | san lorenzo
# Processing Record 40 of Set 12 | hovd
# Processing Record 41 of Set 12 | oktyabrskoye
# Processing Record 42 of Set 12 | sandnessjoen
# Processing Record 43 of Set 12 | gondar
# Processing Record 44 of Set 12 | bela vista do paraiso
# Processing Record 45 of Set 12 | saurimo
# Processing Record 46 of Set 12 | kidal
# Processing Record 47 of Set 12 | ruwi
# Processing Record 48 of Set 12 | harlingen
# Processing Record 49 of Set 12 | akonolinga
# Processing Record 0 of Set 13 | camapua
# Processing Record 1 of Set 13 | tabuleiro do norte
# Processing Record 2 of Set 13 | costinesti
# Processing Record 3 of Set 13 | koster
# Processing Record 4 of Set 13 | nelson bay
# Processing Record 5 of Set 13 | bandarbeyla
# Processing Record 6 of Set 13 | loiza
# Processing Record 7 of Set 13 | toma
# Processing Record 8 of Set 13 | belle glade
# Processing Record 9 of Set 13 | wladyslawowo
# Processing Record 10 of Set 13 | umm durman
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          562
# Lat           562
# Lng           562
# Max Temp      562
# Humidity      562
# Cloudiness    562
# Wind Speed    562
# Country       562
# Date          562
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  punta arenas -53.1500  -70.9167     17.06        27           0
# 1   yerbogachen  61.2767  108.0108    -40.43        98          97
# 2        dikson  73.5069   80.5464    -22.61        94         100
# 3  barreirinhas  -2.7469  -42.8264     25.49        84          21
# 4       ushuaia -54.8000  -68.3000     13.81        44           0
#
#    Wind Speed Country        Date
# 0        5.66      CL  1674424011
# 1        2.88      RU  1674424011
# 2       11.73      RU  1674424012
# 3        2.96      BR  1674424012
# 4        5.14      AR  1674424012

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        punta arenas -53.1500  -70.9167     17.06        27           0
# 1         yerbogachen  61.2767  108.0108    -40.43        98          97
# 2              dikson  73.5069   80.5464    -22.61        94         100
# 3        barreirinhas  -2.7469  -42.8264     25.49        84          21
# 4             ushuaia -54.8000  -68.3000     13.81        44           0
#
#          Wind Speed Country        Date
# City_ID
# 0              5.66      CL  1674424011
# 1              2.88      RU  1674424011
# 2             11.73      RU  1674424012
# 3              2.96      BR  1674424012
# 4              5.14      AR  1674424012

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# city_data_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(6,5), c='DarkGreen',
              # title="City Max Latitude vs Temperature (2023-01-22)")
    
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
plt.figure(figsize=(8,8))
plt.scatter(x_values,y_values, alpha=0.5)

# Incorporate the other graph properties

plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Max Temperature (C)', fontsize=14)
plt.ylim(-55,45)
plt.title('City Max Latitude vs Temperature \n (2023-01-22)', fontweight='bold', fontsize=16)
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
plt.figure(figsize=(8,8))
plt.scatter(x_values,y_values, alpha=0.5)


# Incorporate the other graph properties
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Humidity (%)', fontsize=14)
plt.ylim(0,110)
plt.title('City Latitude vs Humidity \n (2023-01-22)', fontweight='bold', fontsize=16)
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
plt.figure(figsize=(8,8))
plt.scatter(x_values,y_values, alpha=0.5)

# Incorporate the other graph properties
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Cloudiness (%)', fontsize=14)
plt.ylim(-5,105)
plt.title('City Latitude vs Cloudiness \n (2023-01-22)', fontweight='bold', fontsize=16)
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
plt.figure(figsize=(8,8))
plt.scatter(x_values,y_values, alpha=0.5)

# Incorporate the other graph properties
plt.xlabel('Latitude', fontsize=14)
plt.ylabel('Wind Speed (m/s)', fontsize=14)
plt.ylim(-1,16)
plt.title('City Latitude vs Wind Speed \n (2023-01-22)', fontweight='bold', fontsize=16)
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def lin_reg_plot(x_series, y_series):
    
    # calculate linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_series, y_series)
    regress_values = x_series * slope + intercept
    
    # print r-value
    print(f'The r-value is: {rvalue}')
    
    # plot
    plt.scatter(x_series, y_series, alpha=0.5)
    plt.plot(x_series,regress_values, color='red')
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.xlabel('Latitude')
    plt.show()
    
    return line_eq

# since every chart is diffeent , establish ann function to place line_eq on each graph separately
def ann(line_eq, x, y):
    plt.annotate(line_eq,(x,y),fontsize=15,color="red")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          yerbogachen  61.2767  108.0108    -40.43        98          97
# 2               dikson  73.5069   80.5464    -22.61        94         100
# 8        half moon bay  37.4636 -122.4286     16.24        50           0
# 9           nikolskoye  59.7035   30.7861     -5.06        97          70
# 10             okhotsk  59.3833  143.3000    -24.32        80         100
#
#          Wind Speed Country        Date
# City_ID
# 1              2.88      RU  1674424011
# 2             11.73      RU  1674424012
# 8              8.23      US  1674423923
# 9              1.43      RU  1674424014
# 10             5.55      RU  1674424014

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        punta arenas -53.1500 -70.9167     17.06        27           0
# 3        barreirinhas  -2.7469 -42.8264     25.49        84          21
# 4             ushuaia -54.8000 -68.3000     13.81        44           0
# 5            luderitz -26.6481  15.1594     19.30        81           0
# 6        puerto ayora  -0.7393 -90.3518     27.98        92          72
#
#          Wind Speed Country        Date
# City_ID
# 0              5.66      CL  1674424011
# 3              2.96      BR  1674424012
# 4              5.14      AR  1674424012
# 5              7.46     NaN  1674424013
# 6              2.68      EC  1674423955

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere

plt.ylabel('Maximum Temperature (C)')
ann(line_eq, 0,-20)
temp_lat_graph = lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'])
# Out:
# The r-value is: -0.8397856219763753

# %%
# Linear regression on Southern Hemisphere
plt.ylabel('Maximum Temperature (C)')
ann(line_eq, -55,30)
temp_lat_graph = lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
# Out:
# The r-value is: 0.3539358556203263

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.ylabel('Humidity')
ann(line_eq, 40,20)
temp_lat_graph = lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
# Out:
# The r-value is: 0.3628548019835316

# %%
# Southern Hemisphere
plt.ylabel('Humidity')
ann(line_eq, -25,40)
temp_lat_graph = lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
# Out:
# The r-value is: 0.4988481415205989

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.ylabel('Cloudiness')
ann(line_eq, -2,55)
temp_lat_graph = lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
# Out:
# The r-value is: 0.25761059779200557

# %%
# Southern Hemisphere
plt.ylabel('Cloudiness')
ann(line_eq, -55,50)
temp_lat_graph = lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
# Out:
# The r-value is: 0.42570133852205977

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.ylabel('Wind Speed (m/s)')
ann(line_eq, 0,15)
temp_lat_graph = lin_reg_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
# Out:
# The r-value is: 0.09685965665335436

# %%
# Southern Hemisphere
plt.ylabel('Wind Speed (m/s)')
ann(line_eq, -50,10)
temp_lat_graph = lin_reg_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
# Out:
# The r-value is: -0.3020393769265437

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
